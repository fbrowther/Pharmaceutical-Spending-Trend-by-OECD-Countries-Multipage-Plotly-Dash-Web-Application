# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# %%
# add csv
data_path = "Resources/data/data_csv.csv"
data = pd.read_csv(data_path)

data_path2 = "Resources/data/latlongdata.csv"
coords = pd.read_csv(data_path2)

# %%
data
# Out:
#      LOCATION  TIME  PC_HEALTHXP  PC_GDP  USD_CAP FLAG_CODES  TOTAL_SPEND
# 0         AUS  1971       15.992   0.727   35.720        NaN       462.11
# 1         AUS  1972       15.091   0.686   36.056        NaN       475.11
# 2         AUS  1973       15.117   0.681   39.871        NaN       533.47
# 3         AUS  1974       14.771   0.755   47.559        NaN       652.65
# 4         AUS  1975       11.849   0.682   47.561        NaN       660.76
# ...       ...   ...          ...     ...      ...        ...          ...
# 1031      LTU  2012       28.942   1.820  448.728        NaN      1340.70
# 1032      LTU  2013       28.173   1.728  461.178        NaN      1364.02
# 1033      LTU  2014       27.836   1.724  485.245        NaN      1422.92
# 1034      LTU  2015       26.784   1.745  504.422        NaN      1465.30
# 1035      RUS  2015       22.939   1.286  309.900        NaN     44655.62
#
# [1036 rows x 7 columns]

# %%
coords
# Out:
#    Country           Capital   Latitude  Longditude
# 0      AUS          Canberra -35.266667  149.133333
# 1      AUT            Vienna  48.200000   16.366667
# 2      BEL          Brussels  50.833333    4.333333
# 3      BGR             Sofia  42.683333   23.316667
# 4      BRA          Brasilia -15.783333  -47.916667
# 5      CAN            Ottawa  45.416667  -75.700000
# 6      CHL          Santiago -33.450000  -70.666667
# 7      CHE              Bern  46.916667    7.466667
# 8      COL            Bogota   4.600000  -74.083333
# 9      CRI          San Jose   9.933333  -84.083333
# 10     CYP           Nicosia  35.166667   33.366667
# 11     CZE            Prague  50.083333   14.466667
# 12     DEU            Berlin  52.516667   13.400000
# 13     DNK        Copenhagen  55.666667   12.583333
# 14     ESP            Madrid  40.400000   -3.683333
# 15     EST           Tallinn  59.433333   24.716667
# 16     FIN          Helsinki  60.166667   24.933333
# ...

# %%
data.info()
coords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LOCATION     1036 non-null   object
#  1   TIME         1036 non-null   int64
#  2   PC_HEALTHXP  1036 non-null   float64
#  3   PC_GDP       1036 non-null   float64
#  4   USD_CAP      1036 non-null   float64
#  5   FLAG_CODES   63 non-null     object
#  6   TOTAL_SPEND  1036 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 56.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     45 non-null     object
#  1   Capital     45 non-null     object
#  2   Latitude    45 non-null     float64
#  3   Longditude  45 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.5+ KB

# %%
# show data df unique and nunique summary
data_columns = data.columns
for c in data_columns:
    print(c)
    print("============")
    print(data[c].nunique())
    print(data[c].unique())
    print("============")
# Out:
# LOCATION
# ...
# 36
# ['AUS' 'AUT' 'BEL' 'CAN' 'CZE' 'DNK' 'FIN' 'FRA' 'DEU' 'GRC' 'HUN' 'ISL'
#  'IRL' 'ITA' 'JPN' 'KOR' 'LUX' 'MEX' 'NLD' 'NZL' 'NOR' 'POL' 'PRT' 'SVK'
#  'ESP' 'SWE' 'CHE' 'TUR' 'GBR' 'USA' 'EST' 'SVN' 'ISR' 'LVA' 'LTU' 'RUS']
# ...
# TIME
# ...
# 47
# [1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984
#  1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 1970 2016]
# ...
# PC_HEALTHXP
# ...
# 1009
# [15.992 15.091 15.117 ... 27.836 26.784 22.939]
# ...
# PC_GDP
# ...
# 756
# [0.727 0.686 0.681 0.755 0.682 0.63  0.613 0.591 0.523 0.54  0.548 0.564
#  0.58  0.569 0.599 0.582 0.595 0.623 0.677 0.739 0.778 0.819 0.859 0.882
#  0.924 0.95  1.019 1.075 1.194 1.236 1.213 1.244 1.269 1.219 1.225 1.273
#  1.334 1.324 1.315 1.336 1.32  1.306 0.784 0.78  0.801 0.84  0.852 0.854
#  0.876 1.01  1.087 1.17  1.174 1.198 1.238 1.304 1.294 1.277 1.268 1.289
# ...

# %%
# show coords df unique and nunique summary
coords_columns = coords.columns

for c in coords_columns:
    print(c)
    print("============")
    print(coords[c].nunique())
    print(coords[c].unique())
    print("============")
# Out:
# Country
# ...
# 45
# ['AUS' 'AUT' 'BEL' 'BGR' 'BRA' 'CAN' 'CHL' 'CHE' 'COL' 'CRI' 'CYP' 'CZE'
#  'DEU' 'DNK' 'ESP' 'EST' 'FIN' 'FRA' 'GBR' 'GRC' 'HUN' 'HRV' 'IRL' 'ISL'
#  'ISR' 'ITA' 'JPN' 'KOR' 'LTU' 'LUX' 'LVA' 'MEX' 'MLT' 'NLD' 'NOR' 'NZL'
#  'POL' 'PRT' 'ROU' 'SVK' 'SVN' 'SWE' 'TUR' 'USA' 'RUS']
# ...
# Capital
# ...
# 45
# ['Canberra' 'Vienna' 'Brussels' 'Sofia' 'Brasilia' 'Ottawa' 'Santiago'
#  'Bern' 'Bogota' 'San Jose' 'Nicosia' 'Prague' 'Berlin' 'Copenhagen'
#  'Madrid' 'Tallinn' 'Helsinki' 'Paris' 'London' 'Athens' 'Budapest'
#  'Zagreb' 'Dublin' 'Reykjavik' 'Jerusalem' 'Rome' 'Tokyo' 'Seoul'
#  'Vilnius' 'Luxembourg' 'Riga' 'Mexico City' 'Valletta' 'Amsterdam' 'Oslo'
#  'Wellington' 'Warsaw' 'Lisbon' 'Bucharest' 'Bratislava' 'Ljubljana'
#  'Stockholm' 'Ankara' 'Washington, D.C.' ' Moscow']
# ...
# Latitude
# ...
# 45
# [-35.26666667  48.2         50.83333333  42.68333333 -15.78333333
#   45.41666667 -33.45        46.91666667   4.6          9.93333333
# ...

# %%
# !pip install datetime
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'

# %%
import datetime as dt

# %%
data['TIME'] = pd.to_datetime(data['TIME'], format='%Y')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036 entries, 0 to 1035
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LOCATION     1036 non-null   object
#  1   TIME         1036 non-null   datetime64[ns]
#  2   PC_HEALTHXP  1036 non-null   float64
#  3   PC_GDP       1036 non-null   float64
#  4   USD_CAP      1036 non-null   float64
#  5   FLAG_CODES   63 non-null     object
#  6   TOTAL_SPEND  1036 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 56.8+ KB

# %%
data.head()
# Out:
#   LOCATION       TIME  PC_HEALTHXP  PC_GDP  USD_CAP FLAG_CODES  TOTAL_SPEND
# 0      AUS 1971-01-01       15.992   0.727   35.720        NaN       462.11
# 1      AUS 1972-01-01       15.091   0.686   36.056        NaN       475.11
# 2      AUS 1973-01-01       15.117   0.681   39.871        NaN       533.47
# 3      AUS 1974-01-01       14.771   0.755   47.559        NaN       652.65
# 4      AUS 1975-01-01       11.849   0.682   47.561        NaN       660.76

# %%
data['TIME'] = data['TIME'].dt.strftime('%Y')

# %%
data.head()
# Out:
#   LOCATION  TIME  PC_HEALTHXP  PC_GDP  USD_CAP FLAG_CODES  TOTAL_SPEND
# 0      AUS  1971       15.992   0.727   35.720        NaN       462.11
# 1      AUS  1972       15.091   0.686   36.056        NaN       475.11
# 2      AUS  1973       15.117   0.681   39.871        NaN       533.47
# 3      AUS  1974       14.771   0.755   47.559        NaN       652.65
# 4      AUS  1975       11.849   0.682   47.561        NaN       660.76

# %%
# Rename columns
data = data.rename(columns = {
    'LOCATION': 'Country',
    'TIME': 'Years',
    'PC_HEALTHXP':'Percent_of_Health_Spending',
    'PC_GDP':'Percent_of_GDP',
    'USD_CAP':'USD_per_Capita',
    'TOTAL_SPEND': 'Total_Spending_in_Millions_USD'
    })

# %%
data = data.drop('FLAG_CODES', axis=1)

# %%
data.head()
# Out:
#   Country Years  Percent_of_Health_Spending  Percent_of_GDP  USD_per_Capita  \
# 0     AUS  1971                      15.992           0.727          35.720
# 1     AUS  1972                      15.091           0.686          36.056
# 2     AUS  1973                      15.117           0.681          39.871
# 3     AUS  1974                      14.771           0.755          47.559
# 4     AUS  1975                      11.849           0.682          47.561
#
#    Total_Spending_in_Millions_USD
# 0                          462.11
# 1                          475.11
# 2                          533.47
# 3                          652.65
# 4                          660.76

# %%
df = pd.merge(data, coords, how = 'inner', on = 'Country')
df.head()
# Out:
#   Country Years  Percent_of_Health_Spending  Percent_of_GDP  USD_per_Capita  \
# 0     AUS  1971                      15.992           0.727          35.720
# 1     AUS  1972                      15.091           0.686          36.056
# 2     AUS  1973                      15.117           0.681          39.871
# 3     AUS  1974                      14.771           0.755          47.559
# 4     AUS  1975                      11.849           0.682          47.561
#
#    Total_Spending_in_Millions_USD   Capital   Latitude  Longditude
# 0                          462.11  Canberra -35.266667  149.133333
# 1                          475.11  Canberra -35.266667  149.133333
# 2                          533.47  Canberra -35.266667  149.133333
# 3                          652.65  Canberra -35.266667  149.133333
# 4                          660.76  Canberra -35.266667  149.133333

# %%
df = df[['Years', 'Country', 'Capital', 'Latitude','Longditude', 'Percent_of_Health_Spending', 'Percent_of_GDP', 'USD_per_Capita', 'Total_Spending_in_Millions_USD']]
df.head()
# Out:
#   Years Country   Capital   Latitude  Longditude  Percent_of_Health_Spending  \
# 0  1971     AUS  Canberra -35.266667  149.133333                      15.992
# 1  1972     AUS  Canberra -35.266667  149.133333                      15.091
# 2  1973     AUS  Canberra -35.266667  149.133333                      15.117
# 3  1974     AUS  Canberra -35.266667  149.133333                      14.771
# 4  1975     AUS  Canberra -35.266667  149.133333                      11.849
#
#    Percent_of_GDP  USD_per_Capita  Total_Spending_in_Millions_USD
# 0           0.727          35.720                          462.11
# 1           0.686          36.056                          475.11
# 2           0.681          39.871                          533.47
# 3           0.755          47.559                          652.65
# 4           0.682          47.561                          660.76

# %%
df.set_index("Years")
# Out:
#       Country   Capital   Latitude  Longditude  Percent_of_Health_Spending  \
# Years
# 1971      AUS  Canberra -35.266667  149.133333                      15.992
# 1972      AUS  Canberra -35.266667  149.133333                      15.091
# 1973      AUS  Canberra -35.266667  149.133333                      15.117
# 1974      AUS  Canberra -35.266667  149.133333                      14.771
# 1975      AUS  Canberra -35.266667  149.133333                      11.849
# ...       ...       ...        ...         ...                         ...
# 2012      LTU   Vilnius  54.683333   25.316667                      28.942
# 2013      LTU   Vilnius  54.683333   25.316667                      28.173
# 2014      LTU   Vilnius  54.683333   25.316667                      27.836
# 2015      LTU   Vilnius  54.683333   25.316667                      26.784
# 2015      RUS    Moscow  55.751244   37.618423                      22.939
#
# ...

# %% [markdown]
# ## Cleaned Data uploaded onto PostgreSQL

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import pandas as pd
import os

# %%
! pip3 install psycopg2.binary
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'

# %%
pip install config
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
from config import password
from config import username

# %%
protocol = "postgresql"
port = 5433
database_name = "Pharma_db"

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:5433/Pharma_db')
connection = engine.connect()

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['pharmadata']

# %%
df.to_sql('pharmadata', connection, if_exists= 'replace')
# Out:
# 36

# %%
# Query All Records in the the Database
results = pd.read_sql("SELECT * FROM pharmadata", connection)

# %%
# Preview the Data
results.head()
# Out:
#    index Years Country   Capital   Latitude  Longditude  \
# 0      0  1971     AUS  Canberra -35.266667  149.133333
# 1      1  1972     AUS  Canberra -35.266667  149.133333
# 2      2  1973     AUS  Canberra -35.266667  149.133333
# 3      3  1974     AUS  Canberra -35.266667  149.133333
# 4      4  1975     AUS  Canberra -35.266667  149.133333
#
#    Percent_of_Health_Spending  Percent_of_GDP  USD_per_Capita  \
# 0                      15.992           0.727          35.720
# 1                      15.091           0.686          36.056
# 2                      15.117           0.681          39.871
# 3                      14.771           0.755          47.559
# 4                      11.849           0.682          47.561
#
#    Total_Spending_in_Millions_USD
# 0                          462.11
# 1                          475.11
# 2                          533.47
# 3                          652.65
# 4                          660.76

# %% [markdown]
# ## Webscraping for the Latest Pharma News

# %%
# !pip3 install splinter
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'

# %%
# !pip3 install webdriver_manager
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'

# %%
pip install selenium
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip3 install beautifulsoup4
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/Farzana/opt/anaconda3/lib/python3.9/site-packages/ipython-8.2.0.dist-info/METADATA'

# %%
# Import Dependencies
import pymongo
from splinter import Browser
from bs4 import BeautifulSoup as bs
import os
from webdriver_manager.chrome import ChromeDriverManager
import json

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step1: Visit [World Pharma news site](https://www.worldpharmanews.com) and Scrape the Website for latest news title and Preview

# %%
Pharma_news_url = "https://www.worldpharmanews.com"
browser.visit(Pharma_news_url)
html = browser.html
soup = bs(html, "html.parser")
latest_news = soup.find_all("h2", class_="article-title")[0]
latest_news_title = latest_news.get_text()
preview = soup.find_all("section", class_="article-intro clearfix")[0]
latest_news_preview = preview.text

# %%
print(latest_news_title)
# Out:
# 					FDA approves first gene therapy for the treatment of high-risk, non-muscle-invasive bladder cancer

# %%
print(latest_news_preview)
# Out:
# FDAToday, the U.S. Food and Drug Administration approved Adstiladrin (nadofaragene firadenovec-vncg), a non-replicating (cannot multiply in human cells) adenoviral vector based gene therapy indicated for the treatment of adult patients with high-risk Bacillus Calmette-Guérin (BCG)-unresponsive non-muscle-invasive bladder cancer (NMIBC) with carcinoma in situ (CIS) with or without papillary tumors.

# %%
# FINAL DICTIONARY FOR MONGO
    
final_pharma_data = {
"latest_title": latest_news_title,
"latest_paragraph" : latest_news_preview,
}

# %%
browser.quit()
